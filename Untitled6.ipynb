# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0548/VITBML-EDA3/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics

# %% [markdown]
# **code on knn**

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
x=df['Age'].values.reshape(-1,1)
y=df['EstimatedSalary'].values.reshape(-1,1)
print(x)
print(y)
# Out:
# [[19]
#  [35]
#  [26]
#  [27]
#  [19]
#  [27]
#  [27]
#  [32]
#  [25]
#  [35]
#  [26]
#  [26]
#  [20]
#  [32]
#  [18]
#  [29]
#  [47]
#  [45]
#  [46]
#  [48]
#  [45]
#  [47]
#  [48]
#  [45]
#  [46]
#  [47]
#  [49]
#  [47]
#  [29]
#  [31]
#  [31]
#  [27]
#  [21]
#  [28]
#  [27]
#  [35]
#  [33]
#  [30]
#  [26]
#  [27]
#  [27]
#  [33]
#  [35]
#  [30]
#  [28]
#  [23]
#  [25]
#  [27]
#  [30]
#  [31]
#  [24]
#  [18]
#  [29]
#  [35]
#  [27]
#  [24]
#  [23]
#  [28]
#  [22]
#  [32]
#  [27]
#  [25]
#  [23]
#  [32]
#  [59]
#  [24]
#  [24]
#  [23]
#  [22]
#  [31]
#  [25]
#  [24]
#  [20]
#  [33]
#  [32]
#  [34]
#  [18]
#  [22]
#  [28]
#  [26]
#  [30]
#  [39]
#  [20]
#  [35]
#  [30]
#  [31]
#  [24]
#  [28]
#  [26]
#  [35]
#  [22]
#  [30]
#  [26]
#  [29]
#  [29]
#  [35]
#  [35]
#  [28]
#  [35]
#  [28]
#  [27]
#  [28]
#  [32]
#  [33]
#  [19]
#  [21]
#  [26]
#  [27]
#  [26]
#  [38]
#  [39]
#  [37]
#  [38]
#  [37]
#  [42]
#  [40]
#  [35]
#  [36]
#  [40]
#  [41]
#  [36]
#  [37]
#  [40]
#  [35]
#  [41]
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=KNeighborsRegressor(n_neighbors=2,p=2)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform')

# %%
y_pred=model.predict(x_test)

# %%
print(y_pred)
# Out:
# [[ 60000.]
#  [ 78500.]
#  [ 46500.]
#  [115500.]
#  [ 51000.]
#  [ 77500.]
#  [ 79000.]
#  [ 60500.]
#  [ 60000.]
#  [ 61500.]
#  [115500.]
#  [ 78000.]
#  [ 56000.]
#  [ 99500.]
#  [ 34500.]
#  [ 62000.]
#  [ 71000.]
#  [ 77500.]
#  [ 77500.]
#  [ 62000.]
#  [ 92000.]
#  [ 92000.]
#  [ 34500.]
#  [ 51000.]
#  [113500.]
#  [115500.]
#  [ 77500.]
#  [ 34500.]
#  [ 77500.]
#  [ 77500.]
#  [ 79000.]
#  [ 46500.]
#  [102000.]
#  [ 46500.]
#  [ 77500.]
#  [ 45500.]
#  [ 16500.]
#  [ 53000.]
#  [ 42500.]
#  [121000.]
#  [ 47500.]
#  [ 90500.]
#  [ 60500.]
#  [ 53000.]
#  [ 51000.]
#  [ 78000.]
#  [ 42500.]
#  [ 59000.]
#  [ 53000.]
#  [ 90500.]
#  [ 53000.]
#  [ 99500.]
#  [ 90500.]
#  [ 61500.]
#  [ 99500.]
#  [ 42500.]
#  [121000.]
#  [ 99500.]
#  [ 73000.]
#  [102000.]
#  [131000.]
#  [ 16500.]
#  [ 92000.]
#  [ 62000.]
#  [ 77500.]
#  [ 60500.]
#  [ 45500.]
#  [ 35500.]
#  [113500.]
#  [ 79000.]
#  [ 71000.]
#  [ 45500.]
#  [ 28000.]
#  [ 34500.]
#  [ 73000.]
#  [ 42500.]
# ...

# %%
s=pd.DataFrame({'actual':y_test.flatten(),'predict':y_pred.flatten()})
s
# Out:
#     actual   predict
# 0    44000   60000.0
# 1   146000   78500.0
# 2    74000   46500.0
# 3    35000  115500.0
# 4    72000   51000.0
# ..     ...       ...
# 75   86000   42500.0
# 76  134000  115500.0
# 77   78000   77500.0
# 78   80000   56000.0
# 79  149000   45500.0
#
# [80 rows x 2 columns]

# %%
error=metrics.mean_squared_error(y_test,y_pred)
print(error)
# Out:
# 1704509375.0

# %%
list=[]
for k in range(5):
  k=k+1
  model=KNeighborsRegressor(n_neighbors=k)
  model.fit(x_train,y_train)
  y_pred=model.predict(x_test)
  error=metrics.mean_squared_error(y_test,y_pred)
  list.append(error)
  print('for the value of {} the value of error is {}'.format(k,error))
# Out:
# for the value of 1 the value of error is 2210550000.0
# for the value of 2 the value of error is 1704509375.0
# for the value of 3 the value of error is 1456754166.6666665
# for the value of 4 the value of error is 1388034375.0
# for the value of 5 the value of error is 1435599500.0
